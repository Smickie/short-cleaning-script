# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
from gspread_dataframe import get_as_dataframe, set_with_dataframe
import os

path = os.getcwd()

scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name(path + '/keys/keyfilename.json', scope)
client = gspread.authorize(creds)

sheet = client.open_by_url('<SPREADSHEET URL>').sheet1

df = get_as_dataframe(sheet, header=None)

df = df[[0,1]]

df = df.dropna()

df.columns = ["t", "a"]

tdmask = df["t"].str.match(r"^(?!\d{4}-\d{2}-\d{2}).*\d{2}:\d{2}(:\d{2})?")
ymask = df["t"].str.match(r"^(\d{4}-\d{2}-\d{2}).*\d{2}:\d{2}(:\d{2})?")

df1 = df.loc[tdmask]
df2 = df.loc[ymask]

df1["t"] = df1["t"].str.extract(r"(\d+[\d:]\d+)")

df2["t"] = df2["t"].str.extract(r"(\d{4}-\d{1,2}-\d{1,2})")

df2['t'] = df2['t'].replace('', pd.NA).ffill().where(df2['t'].ne(df2['t'].shift()), '')

ndf = pd.concat([df1, df2]).reset_index(drop=True)

english_keywords = ['Annual', 'Notice', 'presents', "resolutions", "revised", "Meeting", "MEETING", "ANNUAL",
                   "appoints", "Appoints", "APPOINTS", "new", "notice", "NOTICE", "Notice", "additional", 
                   "establishing"]

rows_to_remove = df['a'].str.contains('|'.join(english_keywords), case=False, na=False)

ndf = ndf[~rows_to_remove].reset_index(drop=True)

ndf
# Out:
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_90628/978915574.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["t"] = df1["t"].str.extract(r"(\d+[\d:]\d+)")
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_90628/978915574.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["t"] = df2["t"].str.extract(r"(\d{4}-\d{1,2}-\d{1,2})")
# /var/folders/j_/__64n8zj7cl2_v79xs0k7lpm0000gn/T/ipykernel_90628/978915574.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['t'] = df2['t'].replace('', pd.NA).ffill().where(df2['t'].ne(df2['t'].shift()), '')
#              t                                                  a
# 0        08:30  Peab : Klimatförbättrad betong blir standard i...
# 1        08:30  Catena : Catenas årsredovisning med hållbarhet...
# 2        08:30  Nordea : Update to internal allocation framewo...
# 3        08:00  Probi : Kallelse till årsstämma i Probi AB (publ)
# 4        08:00  Peab : Peab bygger fler hus på anstalten i Sörbyn
# 5        08:00  NCC : NCC har tecknat asfaltkontrakt för över ...
# 6        07:30     Smidmek : Bred kompetens vann affär åt Smidmek
# 7   2024-03-25  Arise AB : Återköp av aktier i Arise under vec...
# 8               Holmen : Holmen uppför ytterligare vindkraft p...
# 9               SSAB : SSAB utvalt av amerikanska energimyndig...
# 10              Nethouse : CombinedX-bolaget Nethouse förvärva...
# 11              Probi : Probi publicerar sin årsredovisning fö...
# 12              BE Group AB : BE Group avvecklar förlusttyngd ...
# 13              Swedbank : Swedbank Robur Europafond vinnare i...
# 14              SKF : SKF går in i forsknings- och innovations...
# 15              Essity : Inbjudan till presentation av Essitys...
# 16              Peab : Peab återställer marken runt skredet i ...
# 17  2024-03-22  Medicover : Kallelse till årsstämma i Medicove...
# 18                                      SCA : SCAs årsstämma 2024
# 19              AEROF Sweden Bondco AB (publ) : Aberdeen Europ...
# 20              Holmen : ­Finansiell rapportering för Holmens ...
# 21              Karolinska Universitetssjukhuset : Helgenomsse...
# 22              Hynion AS : Hynion och Toyota Norge ingår sama...
# 23              Nordea : Fler tror på stigande bostadspriser -...
# 24              Viaplay Group : Viaplay Group utser ny finansc...
# 25              NCC : NCC har tecknat ramavtal med Stockholms ...

# %%
sheet.clear()
set_with_dataframe(sheet, ndf, include_index=False, include_column_header=False)
